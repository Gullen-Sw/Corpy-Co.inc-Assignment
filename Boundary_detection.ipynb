# %% [markdown]
# <a href="https://colab.research.google.com/github/Gullen-Sw/Corpy-Co.inc-Assignment/blob/main/Boundary_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Reference
#https://ivo-lee.tistory.com/91
#https://tensorflow.blog/%ed%8c%8c%ec%9d%b4%ec%8d%ac-%eb%a8%b8%ec%8b%a0%eb%9f%ac%eb%8b%9d/1-7-%ec%b2%ab-%eb%b2%88%ec%a7%b8-%ec%95%a0%ed%94%8c%eb%a6%ac%ec%bc%80%ec%9d%b4%ec%85%98-%eb%b6%93%ea%bd%83%ec%9d%98-%ed%92%88%ec%a2%85-%eb%b6%84%eb%a5%98/
#https://note.nkmk.me/python-opencv-imread-imwrite/

import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

#sample_folder = '/content/drive/MyDrive/archive/train'
#good_sample = str(sample_folder) + '/good'
#noise_sample = str(sample_folder) + '/not-good'
sample_folder = '/content/drive/MyDrive/archive/test'

#files_of_good = os.listdir(good_sample)
#number_of_good = len(files_of_good)
#files_of_noise = os.listdir(noise_sample)
#number_of_noise = len(files_of_noise)
files = os.listdir(sample_folder)
number_of_files = len(files)

for i in range(number_of_files):
    file = files[i]
    path = os.path.join(sample_folder, file)
    im = cv2.imread(path)

    #=========================Boundary Detection================================
    median_intensity = np.median(im) # 픽셀 강도의 중간값을 계산

    # 중간 픽셀 강도에서 위아래 1 표준 편차 떨어진 값을 임계값으로 지정합니다.
    lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
    upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))

    # 캐니 경계선 감지기를 적용합니다.
    image_canny = cv2.Canny(im, lower_threshold, upper_threshold)
    plt.imshow(image_canny, cmap="gray"), plt.axis("off") # 이미지 출력
    plt.show()
    cv2.imwrite('/content/drive/MyDrive/archive/test/edge' +str(i)+'.png', image_canny)

"""
for i in range(number_of_good):
    file = files_of_good[i]
    path = str(good_sample) + '/' + str(file)
    im = cv2.imread(path)

    #=========================Boundary Detection================================
    median_intensity = np.median(im) # 픽셀 강도의 중간값을 계산

    # 중간 픽셀 강도에서 위아래 1 표준 편차 떨어진 값을 임계값으로 지정합니다.
    lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
    upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))

    # 캐니 경계선 감지기를 적용합니다.
    image_canny = cv2.Canny(im, lower_threshold, upper_threshold)
    plt.imshow(image_canny, cmap="gray"), plt.axis("off") # 이미지 출력
    plt.show()
    cv2.imwrite('/content/drive/MyDrive/archive/train/good_edge/good_edge' +str(i)+'.png', image_canny)

for j in range(number_of_noise):
    file = files_of_noise[j]
    path = str(noise_sample) + '/' + str(file)
    img = cv2.imread(path)

    #=========================Boundary Detection================================
    median_intensity = np.median(img) # 픽셀 강도의 중간값을 계산

    # 중간 픽셀 강도에서 위아래 1 표준 편차 떨어진 값을 임계값으로 지정합니다.
    lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
    upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))

    # 캐니 경계선 감지기를 적용합니다.
    image_canny = cv2.Canny(img, lower_threshold, upper_threshold)
    plt.imshow(image_canny, cmap="gray"), plt.axis("off") # 이미지 출력
    plt.show()
    cv2.imwrite('/content/drive/MyDrive/archive/train/noise_edge/noise_edge' +str(j)+'.png', image_canny)
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-d8d69dc5d54c> in <module>()
#      28
#      29     #=========================Boundary Detection================================
# ---> 30     median_intensity = np.median(im) # 픽셀 강도의 중간값을 계산
#      31
#      32     # 중간 픽셀 강도에서 위아래 1 표준 편차 떨어진 값을 임계값으로 지정합니다.
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3654     """
#    3655     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3656                     overwrite_input=overwrite_input)
#    3657     if keepdims:
#    3658         return r.reshape(k)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3562         keepdim = (1,) * a.ndim
#    3563
# ...
